# %% [markdown]
# # Question 3

# %%
import numpy as np
import pandas as pd

# %%
from scipy import stats
from scipy.stats import norm
from scipy.stats import chi2_contingency

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b22c38b-5eb6-47d7-9079-5a82e8c970bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b22c38b-5eb6-47d7-9079-5a82e8c970bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("BuyerRatio.csv")

# %%
data
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %% [markdown]
# Selecting the requird data

# %%
dt = data.iloc[:,1:6]
dt
# Out:
#    East  West  North  South
# 0    50   142    131     70
# 1   435  1523   1356    750

# %%
dt.values
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %% [markdown]
# chi2 contingency test

# %%
test = stats.chi2_contingency(dt)

# %%
test
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %% [markdown]
# pvalue < 0.05 so we will choose to reject null hypothesis & accept alternate hypothesis

# %% [markdown]
# # Question 4

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-16ff405b-28af-475a-a576-d7d8b08c07c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16ff405b-28af-475a-a576-d7d8b08c07c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
CO = pd.read_csv("Costomer+OrderForm.csv")

# %%
CO
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
print(CO['Phillippines'].value_counts(),
      CO['Indonesia'].value_counts(),
      CO['Malta'].value_counts(),
      CO['India'].value_counts())
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64 Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64 Error Free    269
# Defective      31
# Name: Malta, dtype: int64 Error Free    280
# Defective      20
# Name: India, dtype: int64

# %% [markdown]
# Creating a contingency table from the dataset by selecting teh values of each country

# %%
values = np.array([[271,267,269,280],[29,33,31,20]])
values
# Out:
# array([[271, 267, 269, 280],
#        [ 29,  33,  31,  20]])

# %%
test2 = chi2_contingency(values)
test2
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
statistic, pvalue, dof, expected = chi2_contingency(values)

# %%
pvalue
# Out:
# 0.2771020991233135

# %% [markdown]
# We got teh pvalue as 0.27 comparing teh p value with alpha = 0.05 so pvalue is greater than 0.05 so we will reject alternate hypothesis and accept NULL hypotheis
